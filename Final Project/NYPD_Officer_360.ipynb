# %% [markdown]
# <a href="https://colab.research.google.com/github/lbayly-dev/CCRB-data/blob/main/NYPD_Officer_360.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import necessary libraries
import requests
import pandas as pd
import io
import matplotlib.pyplot as plt
import seaborn as sns

# Pulling Police Officer csv file from the NYC Open Data Portal
csv_url = 'https://data.cityofnewyork.us/api/views/2fir-qns4/rows.csv?accessType=DOWNLOAD'

try:
    # Send a GET request to the URL
    response = requests.get(csv_url)
    response.raise_for_status() # Raise an exception for HTTP errors (4xx or 5xx)

    # Read the content into a pandas DataFrame
    df = pd.read_csv(io.StringIO(response.text))

    print(f"Successfully downloaded CSV from {csv_url} and loaded into a DataFrame.")

    # Display the first 5 rows of the DataFrame
    display(df.head())

except requests.exceptions.RequestException as e:
    print(f"Error downloading the CSV file: {e}")
except pd.errors.EmptyDataError:
    print("Error: The downloaded file is empty or not a valid CSV.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Successfully downloaded CSV from https://data.cityofnewyork.us/api/views/2fir-qns4/rows.csv?accessType=DOWNLOAD and loaded into a DataFrame.
#    As Of Date  Tax ID Active Per Last Reported Status  \
# 0  05/21/2026  978322                             Yes
# 1  05/21/2026  956161                             Yes
# 2  05/21/2026  904445                              No
# 3  05/21/2026  910330                              No
# 4  05/21/2026  938622                              No
#
#   Last Reported Active Date Officer First Name Officer Last Name Officer Race  \
# 0    05/01/2026 04:31:35 PM             Carlos           Vasquez     Hispanic
# 1    05/01/2026 04:31:35 PM             Sylvia            Penalo     Hispanic
# 2    04/19/2000 05:41:39 PM             Daniel          Margaris        White
# 3    02/04/2009 01:21:02 PM                Jon             Crose        White
# 4    07/01/2025 11:12:21 AM              Jorge           Grullon     Hispanic
#
#   Officer Gender Current Rank Abbreviation    Current Rank Current Command  \
# 0           Male                        PO  Police Officer         042 PCT
# 1         Female                        PO  Police Officer         DB CEIS
# 2           Male                       POM  Police Officer         088 PCT
# 3           Male                       POM  Police Officer         TB DT04
# 4           Male                        PO  Police Officer         033 PCT
#
#    Shield No  Total Complaints  Total Substantiated Complaints
# 0    21062.0                 0                               0
# 1    13158.0                 0                               0
# 2    11288.0                 0                               0
# 3     3119.0                 1                               0
# 4    31251.0                11                               1

# %%
# Pulling Allegations csv file from the NYC Open Data Portal
allegations_url = 'https://data.cityofnewyork.us/api/views/6xgr-kwjq/rows.csv?accessType=DOWNLOAD'

try:
    response_allegations = requests.get(allegations_url)
    response_allegations.raise_for_status()
    df_allegations = pd.read_csv(io.StringIO(response_allegations.text))

    print(f"Successfully downloaded CSV from {allegations_url} and loaded into df_allegations.")
    display(df_allegations.head())

except requests.exceptions.RequestException as e:
    print(f"Error downloading the Allegations CSV file: {e}")
except pd.errors.EmptyDataError:
    print("Error: The downloaded Allegations file is empty or not a valid CSV.")
except Exception as e:
    print(f"An unexpected error occurred with Allegations CSV: {e}")
# Out:
# Successfully downloaded CSV from https://data.cityofnewyork.us/api/views/6xgr-kwjq/rows.csv?accessType=DOWNLOAD and loaded into df_allegations.
#    As Of Date  Complaint Id  Complaint Officer Number    Tax ID  \
# 0  05/21/2026     201809420                         1       NaN
# 1  05/21/2026     200204705                         1  919349.0
# 2  05/21/2026     200309008                         1       NaN
# 3  05/21/2026     202412639                         2  956706.0
# 4  05/21/2026     200507353                         5       NaN
#
#   Officer Rank Abbreviation At Incident Officer Rank At Incident  \
# 0                                   NaN                      NaN
# 1                                   POM           Police Officer
# 2                                   NaN                      NaN
# 3                                    PO           Police Officer
# 4                                   NaN                      NaN
#
#   Officer Command At Incident  Officer Days On Force At Incident  \
# 0                     NARCBSI                                0.0
# 1                     PBBN AC                             1915.0
# 2                         NaN                                NaN
# 3                     PSB CRT                             3783.0
# 4                         NaN                                0.0
#
#    Allegation Record Identity           FADO Type           Allegation  \
# 0                     1037164  Abuse of Authority     Threat of arrest
# 1                      296552               Force       Physical force
# 2                      337853  Abuse of Authority  Frisk and/or search
# 3                     1302551               Force              Vehicle
# 4                      444182               Force              Vehicle
#
#   Victim/Alleged Victim Age Range At Incident Victim/Alleged Victim Gender  \
# 0                              24 < Age <= 29                     Male/Man
# 1                              14 < Age <= 17                     Male/Man
# 2                              17 < Age <= 20                     Male/Man
# 3                              24 < Age <= 29                     Male/Man
# 4                              34 < Age <= 39                 Female/Woman
#
#   Victim / Alleged Victim Race (Legacy)  \
# 0                                 White
# 1                                 Black
# 2                                 Black
# 3                                   NaN
# 4                                 Black
#
#             Victim / Alleged Victim Race / Ethnicity  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Black and/or African American (R); Other Hispa...
# 4                                                NaN
#
#   CCRB Investigations Division Recommendation CCRB Allegation Disposition  \
# 0                   Complainant Uncooperative   Complainant Uncooperative
# 1                               Substantiated     Substantiated (Charges)
# 2                     Officer(s) Unidentified     Officer(s) Unidentified
# 3                                   Unfounded                   Unfounded
# 4                                   Unfounded                   Unfounded
#
#   NYPD Allegation Disposition
# 0                         NaN
# 1      Charge Dismissed - DCT
# 2                         NaN
# 3                         NaN
# 4                         NaN

# %%
# Pulling Complaints csv file from the NYC Open Data Portal
complaints_url = 'https://data.cityofnewyork.us/api/views/2mby-ccnw/rows.csv?accessType=DOWNLOAD'

try:
    response_complaints = requests.get(complaints_url)
    response_complaints.raise_for_status()
    df_complaints = pd.read_csv(io.StringIO(response_complaints.text))

    print(f"Successfully downloaded CSV from {complaints_url} and loaded into df_complaints.")
    display(df_complaints.head())

except requests.exceptions.RequestException as e:
    print(f"Error downloading the Complaints CSV file: {e}")
except pd.errors.EmptyDataError:
    print("Error: The downloaded Complaints file is empty or not a valid CSV.")
except Exception as e:
    print(f"An unexpected error occurred with Complaints CSV: {e}")
# Out:
# Successfully downloaded CSV from https://data.cityofnewyork.us/api/views/2mby-ccnw/rows.csv?accessType=DOWNLOAD and loaded into df_complaints.
#    As Of Date  Complaint Id Incident Date  Incident Hour  \
# 0    20260521     201114589    2011-11-06           21.0
# 1    20260521     200600231    2005-12-31           15.0
# 2    20260521     201210546    2012-08-11           22.0
# 3    20260521     202305785    2023-05-05           12.0
# 4    20260521     202207957    2022-11-14           18.0
#
#        CCRB Received Date              Close Date  \
# 0  11/10/2011 11:17:57 AM  12/30/2011 09:48:43 AM
# 1  01/04/2006 12:00:00 AM  05/01/2006 12:29:18 PM
# 2  08/15/2012 01:29:25 PM  02/14/2013 11:17:48 AM
# 3  06/27/2023 12:57:00 PM  10/12/2023 02:00:52 PM
# 4  11/20/2022 01:26:00 PM  03/13/2023 03:18:33 PM
#
#   Borough Of Incident Occurrence Precinct Of Incident Occurrence  \
# 0                      Manhattan                              01
# 1                       Brooklyn                              88
# 2                       Brooklyn                             NaN
# 3                          Bronx                              50
# 4                          Bronx                              52
#
#   Location Type Of Incident                     Reason for Police Contact  \
# 0            Street/highway                            C/V telephoned PCT
# 1            Street/highway  PD suspected C/V of violation/crime - street
# 2            Street/highway                                         Other
# 3            Street/highway  PD suspected C/V of violation/crime - street
# 4           Police building                         CV already in custody
#
#         Outcome Of Police Encounter CCRB Complaint Disposition BWC Evidence  \
# 0    Arrest - other violation/crime        Complaint Withdrawn           No
# 1  No arrest made or summons issued  Complainant Uncooperative           No
# 2  No arrest made or summons issued  Complainant Uncooperative           No
# 3   Summons - other violation/crime                   Mediated          Yes
# 4         Arrest - resisting arrest  Complainant Uncooperative          Yes
#
#   Video Evidence
# 0             No
# 1             No
# 2             No
# 3             No
# 4            Yes

# %%
# Filter file for active officers
filtered_df = (df['Active Per Last Reported Status'] == 'Yes')

# Convert filtered_df Series to a DataFrame containing only active officers
active_officers_df = df[filtered_df].copy()

# Perform an inner join between active_officers_df and df_allegations on 'Tax ID'
merged_active_officers_allegations = pd.merge(active_officers_df, df_allegations, on='Tax ID', how='inner', suffixes=('_officer', '_allegation'))

print(merged_active_officers_allegations.columns.tolist())

# Perform an inner join between merged_active_officers_allegations and df_complaints on 'Complaint Id'
merged_active_officers_allegations_complaints = pd.merge(merged_active_officers_allegations, df_complaints, on='Complaint Id', how='inner', suffixes=('_allegation_complaint', '_incident_detail'))

print(merged_active_officers_allegations_complaints.columns.tolist())

# Filter file for incidents in a particular borough (Manhattan, Queens, Brooklyn, Bronx, Staten Island) - currently has Manhattan in the code
filtered_merged_df = merged_active_officers_allegations_complaints[merged_active_officers_allegations_complaints['Borough Of Incident Occurrence'] == 'Manhattan'].copy()

print("\nShape of the complaints DataFrame (df_complaints):")
print(df_complaints.shape)
print("Shape of the allegations DataFrame (merged_active_officers_allegations):")
print(merged_active_officers_allegations.shape)
print("Shape of the inner merged DataFrame before penalties:")
print(merged_active_officers_allegations_complaints.shape)
print("Shape of the filtered inner merged DataFrame (Manhattan):")
print(filtered_merged_df.shape)
# Out:
# ['As Of Date_officer', 'Tax ID', 'Active Per Last Reported Status', 'Last Reported Active Date', 'Officer First Name', 'Officer Last Name', 'Officer Race', 'Officer Gender', 'Current Rank Abbreviation', 'Current Rank', 'Current Command', 'Shield No', 'Total Complaints', 'Total Substantiated Complaints', 'As Of Date_allegation', 'Complaint Id', 'Complaint Officer Number', 'Officer Rank Abbreviation At Incident', 'Officer Rank At Incident', 'Officer Command At Incident', 'Officer Days On Force At Incident', 'Allegation Record Identity', 'FADO Type', 'Allegation', 'Victim/Alleged Victim Age Range At Incident', 'Victim/Alleged Victim Gender', 'Victim / Alleged Victim Race (Legacy)', 'Victim / Alleged Victim Race / Ethnicity', 'CCRB Investigations Division Recommendation', 'CCRB Allegation Disposition', 'NYPD Allegation Disposition']
# ['As Of Date_officer', 'Tax ID', 'Active Per Last Reported Status', 'Last Reported Active Date', 'Officer First Name', 'Officer Last Name', 'Officer Race', 'Officer Gender', 'Current Rank Abbreviation', 'Current Rank', 'Current Command', 'Shield No', 'Total Complaints', 'Total Substantiated Complaints', 'As Of Date_allegation', 'Complaint Id', 'Complaint Officer Number', 'Officer Rank Abbreviation At Incident', 'Officer Rank At Incident', 'Officer Command At Incident', 'Officer Days On Force At Incident', 'Allegation Record Identity', 'FADO Type', 'Allegation', 'Victim/Alleged Victim Age Range At Incident', 'Victim/Alleged Victim Gender', 'Victim / Alleged Victim Race (Legacy)', 'Victim / Alleged Victim Race / Ethnicity', 'CCRB Investigations Division Recommendation', 'CCRB Allegation Disposition', 'NYPD Allegation Disposition', 'As Of Date', 'Incident Date', 'Incident Hour', 'CCRB Received Date', 'Close Date', 'Borough Of Incident Occurrence', 'Precinct Of Incident Occurrence', 'Location Type Of Incident', 'Reason for Police Contact', 'Outcome Of Police Encounter', 'CCRB Complaint Disposition', 'BWC Evidence', 'Video Evidence']
#
# Shape of the complaints DataFrame (df_complaints):
# (139935, 14)
# Shape of the allegations DataFrame (merged_active_officers_allegations):
# (124567, 31)
# Shape of the inner merged DataFrame before penalties:
# (124567, 44)
# Shape of the filtered inner merged DataFrame (Manhattan):
# (26473, 44)

# %%
# Print columns in file to decide which columns to keep
print(filtered_merged_df.columns.tolist())
# Out:
# ['As Of Date_officer', 'Tax ID', 'Active Per Last Reported Status', 'Last Reported Active Date', 'Officer First Name', 'Officer Last Name', 'Officer Race', 'Officer Gender', 'Current Rank Abbreviation', 'Current Rank', 'Current Command', 'Shield No', 'Total Complaints', 'Total Substantiated Complaints', 'As Of Date_allegation', 'Complaint Id', 'Complaint Officer Number', 'Officer Rank Abbreviation At Incident', 'Officer Rank At Incident', 'Officer Command At Incident', 'Officer Days On Force At Incident', 'Allegation Record Identity', 'FADO Type', 'Allegation', 'Victim/Alleged Victim Age Range At Incident', 'Victim/Alleged Victim Gender', 'Victim / Alleged Victim Race (Legacy)', 'Victim / Alleged Victim Race / Ethnicity', 'CCRB Investigations Division Recommendation', 'CCRB Allegation Disposition', 'NYPD Allegation Disposition', 'As Of Date', 'Incident Date', 'Incident Hour', 'CCRB Received Date', 'Close Date', 'Borough Of Incident Occurrence', 'Precinct Of Incident Occurrence', 'Location Type Of Incident', 'Reason for Police Contact', 'Outcome Of Police Encounter', 'CCRB Complaint Disposition', 'BWC Evidence', 'Video Evidence']

# %%
# Drop the columns that are not needed - can easily be edited to include or remove columns
filtered_merged_df = filtered_merged_df.drop(columns=['Victim / Alleged Victim Race (Legacy)', 'Active Per Last Reported Status', 'Last Reported Active Date', 'As Of Date_allegation', 'As Of Date', 'CCRB Investigations Division Recommendation'])

print(filtered_merged_df.columns.tolist())
# Out:
# ['As Of Date_officer', 'Tax ID', 'Officer First Name', 'Officer Last Name', 'Officer Race', 'Officer Gender', 'Current Rank Abbreviation', 'Current Rank', 'Current Command', 'Shield No', 'Total Complaints', 'Total Substantiated Complaints', 'Complaint Id', 'Complaint Officer Number', 'Officer Rank Abbreviation At Incident', 'Officer Rank At Incident', 'Officer Command At Incident', 'Officer Days On Force At Incident', 'Allegation Record Identity', 'FADO Type', 'Allegation', 'Victim/Alleged Victim Age Range At Incident', 'Victim/Alleged Victim Gender', 'Victim / Alleged Victim Race / Ethnicity', 'CCRB Allegation Disposition', 'NYPD Allegation Disposition', 'Incident Date', 'Incident Hour', 'CCRB Received Date', 'Close Date', 'Borough Of Incident Occurrence', 'Precinct Of Incident Occurrence', 'Location Type Of Incident', 'Reason for Police Contact', 'Outcome Of Police Encounter', 'CCRB Complaint Disposition', 'BWC Evidence', 'Video Evidence']

# %%
# Reformat dates so that they can be read by AirTable
date_columns = [
    'As Of Date_officer',
    'Incident Date',
    'CCRB Received Date',
    'Close Date'
]

for col in date_columns:
    if col in filtered_merged_df.columns:
        # Convert to datetime, coercing errors will turn unparseable dates into NaT (Not a Time)
        filtered_merged_df[col] = pd.to_datetime(filtered_merged_df[col], errors='coerce')
        # Format as 'YYYY-MM-DD' string, NaT values will become NaN
        filtered_merged_df[col] = filtered_merged_df[col].dt.strftime('%Y-%m-%d')

print("Date columns formatted to 'YYYY-MM-DD'. Displaying first 5 rows to verify:")
display(filtered_merged_df[date_columns].head())
# Out:
# /tmp/ipykernel_1082/1778173840.py:11: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   filtered_merged_df[col] = pd.to_datetime(filtered_merged_df[col], errors='coerce')
# Date columns formatted to 'YYYY-MM-DD'. Displaying first 5 rows to verify:
#    As Of Date_officer Incident Date CCRB Received Date  Close Date
# 0          2026-05-21    2017-12-15         2017-12-26  2018-02-28
# 37         2026-05-21    2008-12-09         2008-12-10  2009-09-02
# 38         2026-05-21    2011-04-12         2011-04-14  2011-07-15
# 65         2026-05-21    2017-05-14         2017-05-16  2017-11-22
# 66         2026-05-21    2018-04-17         2018-04-19  2018-10-16

# %%
# Select the first 100 rows - reduce size of data table if necessary
first_100_rows_df = filtered_merged_df.head(100)

# Export the filtered DataFrame to a CSV file
output_filename_100_rows = 'manhattan_police_complaints_100_rows.csv'
first_100_rows_df.to_csv(output_filename_100_rows, index=False)

# Download the csv file
from google.colab import files
files.download('manhattan_police_complaints_100_rows.csv')
